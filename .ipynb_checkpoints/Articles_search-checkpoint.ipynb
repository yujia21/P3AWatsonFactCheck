# %%
# !jupyter nbconvert --to script Articles_search.ipynb

from watson_developer_cloud import AlchemyDataNewsV1
import json
# Out:
# [NbConvertApp] Converting notebook Articles_search.ipynb to script
# [NbConvertApp] Writing 1624 bytes to Articles_search.py

# %%
from API_Key import *
from Keyword_input import extract_keywords
alchemy_data_news = AlchemyDataNewsV1(api_key = api_key_chosen)
# Out:
# [NbConvertApp] Converting notebook Keyword_input.ipynb to script
# [NbConvertApp] Writing 3282 bytes to Keyword_input.py

# %%
def search_from_keywords(keywords):
    
    # keywords is a dictionnary with 'subjects' (dictionnary with 'Person', 'Country', 'Organization', 'Unsorted Subjects'),
    # 'relations', 'objects', 'negations'
    
    interesting_keywords = []
    for intermediate_list in list(keywords['subjects'].values()):
        interesting_keywords += intermediate_list
    
    for word in keywords['objects']:
        if word not in interesting_keywords:
            interesting_keywords.append(word)
    
    tts='A['
    for keyword in interesting_keywords:
        tts += keyword+'^'
    tts = tts[:-1]+']'

    results = alchemy_data_news.get_news_documents(
                                                   start='now-1d',
                                                   end='now',
                                                   return_fields=['enriched.url.title',
                                                                  'enriched.url.url',
                                                                  'enriched.url.text',
                                                                  'enriched.url.author',
                                                                  'enriched.url.publicationDate'],
                                                   query_fields={'q.enriched.url.text': tts})
    
    #print(json.dumps(results, indent=2))
    
    text_list = [doc['source']['enriched']['url']['text'] for doc in results['result']['docs']]
    
    keywords_list = [extract_keywords(text) for text in text_list]
    
    return keywords_list

# %%
# Comment if using from Interface, decomment to test.
k = {'subjects': {'Person': ['Trump'], 'Unsorted Subjects': []}, 'objects': ['president']}

search_from_keywords(k)
# Out:
# A[Trump^president]
# This fact is about:
# Unsorted Subjects :
# ['Muslim', 'countries']
# Country :
# ['Syria', 'Yemen', 'Libya', 'Somalia', 'Iran', 'Sudan', 'Iraq', 'U.S.']
# Person :
# ['Trump']
#
# The relations and verbs involved are:
# ['worksAs', 'worksAs', 'affiliatedWith', 'partOfMany']
#
# The objects of these relations are:
# ['president', 'executive', 'Muslim', 'countries']
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['Russian', 'Vladimir Putin', 'Asked', 'Asked']
# Person :
# ['President Donald Trump', 'Dmitry Peskov', 'Vladimir Putin']
#
# The relations and verbs involved are:
# ['worksAs', 'worksAs', 'managerOf', 'spokespersonFor', 'agentOf', 'timeOf']
#
# The objects of these relations are:
# ['President', 'executive', 'Russian', 'Vladimir Putin', 'Asked', 'Asked']
#
#
# ## Negations ##
# There is a negation : ['not']
#
#
# This fact is about:
# Unsorted Subjects :
# ['administration', 'UN', 'administration', 'administration', 'reported']
# Country :
# ['US']
# Person :
# ['Donald Trump']
# Organization :
# ['UN']
#
# The relations and verbs involved are:
# ['worksAs', 'worksAs', 'managerOf', 'partOf', 'managerOf', 'partOf', 'timeOf']
#
# The objects of these relations are:
# ['President', 'executive', 'administration', 'UN', 'administration', 'administration', 'reported']
#
#
#
# This fact is about:
#
# The relations and verbs involved are:
# []
#
# The objects of these relations are:
# []
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['United States']
# Country :
# ['United States']
# Person :
# ['Donald Trump']
#
# The relations and verbs involved are:
# ['worksAs', 'employedBy']
#
# The objects of these relations are:
# ['President', 'United States']
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['Australia', 'Business Survey', 'DE', 'Lautenschlaeger', 'Germany', 'Mexican', 'US', 'Senate', 'Democratic', 'US', 'UBS Consumption Indicator']
# Country :
# ['US', 'France', 'Australia', 'Germany', 'Japan', 'Sweden', 'India', 'Poland']
# Person :
# ['Trump', 'Schumer']
# Organization :
# ['Senate']
#
# The relations and verbs involved are:
# ['worksAs', 'worksAs', 'employedBy', 'managerOf', 'hasAttribute', 'basedIn', 'locatedAt', 'locatedAt', 'partOf', 'partOf', 'employedBy', 'basedIn', 'managerOf']
#
# The objects of these relations are:
# ['President', 'executive', 'Australia', 'Business Survey', 'DE', 'Lautenschlaeger', 'Germany', 'Mexican', 'US', 'Senate', 'Democratic', 'US', 'UBS Consumption Indicator']
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['Philippines', 'Philippines', 'report']
# Country :
# ['Philippines']
# Organization :
# ['Philippine Stock Exchange']
#
# The relations and verbs involved are:
# ['locatedAt', 'locatedAt', 'agentOf']
#
# The objects of these relations are:
# ['Philippines', 'Philippines', 'report']
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['said', 'said']
# Person :
# ['President Donald Trump']
# Organization :
# ['Department of Homeland Security.']
#
# The relations and verbs involved are:
# ['worksAs', 'agentOf', 'timeOf']
#
# The objects of these relations are:
# ['executive', 'said', 'said']
#
#
# ## Negations ##
# There is a negation : ['not']
#
#
# This fact is about:
# Country :
# ['United States']
#
# The relations and verbs involved are:
# []
#
# The objects of these relations are:
# []
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['sworn in', 'US', 'Chinese', 'Russia']
# Country :
# ['US', 'Russia', 'China']
# Person :
# ['Donald J. Trump', 'Vladimir Putin']
#
# The relations and verbs involved are:
# ['worksAs', 'affectedBy', 'employedBy', 'employedBy', 'employedBy']
#
# The objects of these relations are:
# ['president', 'sworn in', 'US', 'Chinese', 'Russia']
#
#
#
# ----------------------------------------------
# [{'negations': [], 'subjects': {'Unsorted Subjects': ['Muslim', 'countries'], 'Country': ['Syria', 'Yemen', 'Libya', 'Somalia', 'Iran', 'Sudan', 'Iraq', 'U.S.'], 'Person': ['Trump'], 'Organization': []}, 'relations': ['worksAs', 'worksAs', 'affiliatedWith', 'partOfMany'], 'objects': ['president', 'executive', 'Muslim', 'countries']}, {'negations': ['not'], 'subjects': {'Unsorted Subjects': ['Russian', 'Vladimir Putin', 'Asked', 'Asked'], 'Country': [], 'Person': ['President Donald Trump', 'Dmitry Peskov', 'Vladimir Putin'], 'Organization': []}, 'relations': ['worksAs', 'worksAs', 'managerOf', 'spokespersonFor', 'agentOf', 'timeOf'], 'objects': ['President', 'executive', 'Russian', 'Vladimir Putin', 'Asked', 'Asked']}, {'negations': [], 'subjects': {'Unsorted Subjects': ['administration', 'UN', 'administration', 'administration', 'reported'], 'Country': ['US'], 'Person': ['Donald Trump'], 'Organization': ['UN']}, 'relations': ['worksAs', 'worksAs', 'managerOf', 'partOf', 'managerOf', 'partOf', 'timeOf'], 'objects': ['President', 'executive', 'administration', 'UN', 'administration', 'administration', 'reported']}, {'negations': [], 'subjects': {'Unsorted Subjects': [], 'Country': [], 'Person': [], 'Organization': []}, 'relations': [], 'objects': []}, {'negations': [], 'subjects': {'Unsorted Subjects': ['United States'], 'Country': ['United States'], 'Person': ['Donald Trump'], 'Organization': []}, 'relations': ['worksAs', 'employedBy'], 'objects': ['President', 'United States']}, {'negations': [], 'subjects': {'Unsorted Subjects': ['Australia', 'Business Survey', 'DE', 'Lautenschlaeger', 'Germany', 'Mexican', 'US', 'Senate', 'Democratic', 'US', 'UBS Consumption Indicator'], 'Country': ['US', 'France', 'Australia', 'Germany', 'Japan', 'Sweden', 'India', 'Poland'], 'Person': ['Trump', 'Schumer'], 'Organization': ['Senate']}, 'relations': ['worksAs', 'worksAs', 'employedBy', 'managerOf', 'hasAttribute', 'basedIn', 'locatedAt', 'locatedAt', 'partOf', 'partOf', 'employedBy', 'basedIn', 'managerOf'], 'objects': ['President', 'executive', 'Australia', 'Business Survey', 'DE', 'Lautenschlaeger', 'Germany', 'Mexican', 'US', 'Senate', 'Democratic', 'US', 'UBS Consumption Indicator']}, {'negations': [], 'subjects': {'Unsorted Subjects': ['Philippines', 'Philippines', 'report'], 'Country': ['Philippines'], 'Person': [], 'Organization': ['Philippine Stock Exchange']}, 'relations': ['locatedAt', 'locatedAt', 'agentOf'], 'objects': ['Philippines', 'Philippines', 'report']}, {'negations': ['not'], 'subjects': {'Unsorted Subjects': ['said', 'said'], 'Country': [], 'Person': ['President Donald Trump'], 'Organization': ['Department of Homeland Security.']}, 'relations': ['worksAs', 'agentOf', 'timeOf'], 'objects': ['executive', 'said', 'said']}, {'negations': [], 'subjects': {'Unsorted Subjects': [], 'Country': ['United States'], 'Person': [], 'Organization': []}, 'relations': [], 'objects': []}, {'negations': [], 'subjects': {'Unsorted Subjects': ['sworn in', 'US', 'Chinese', 'Russia'], 'Country': ['US', 'Russia', 'China'], 'Person': ['Donald J. Trump', 'Vladimir Putin'], 'Organization': []}, 'relations': ['worksAs', 'affectedBy', 'employedBy', 'employedBy', 'employedBy'], 'objects': ['president', 'sworn in', 'US', 'Chinese', 'Russia']}]
# {'result': {'docs': [{'id': 'MjYzMDI0ODE1OHwxNDg1NDIzMzIy',
#     'source': {'enriched': {'url': {'author': 'AP White House Correspondent\n \t\t\t\t\t\t\t \t\t\t\t\t\t\t\t \t\t \t3:59 a.m. Thursday',
#        'publicationDate': {'confident': 'no', 'date': '20170126T000000'},
#        'text': "Sometime this week, Trump is expected to pause the flow of all refugees to the U.S. and indefinitely bar those fleeing war-torn Syria. The president's upcoming order is also expected to suspend issuing visas for people from several predominantly Muslim countries — Iran, Iraq, Libya, Somalia, Sudan, Syria and Yemen — for at least 30 days, according to a draft executive order obtained by The Associated Press. ...",
#        'title': "Trump's immigration actions mark sharp shift in US policy",
#        'url': 'http://www.palmbeachpost.com/news/national-govt--politics/trump-immigration-actions-mark-sharp-shift-policy/sUhjmWSrLnFRnjBMsydsVO/'}}},
#     'timestamp': 1485423322},
#    {'id': 'MjYzMDU2ODEzNXwxNDg1NDIzMzIw',
#     'source': {'enriched': {'url': {'author': 'The Associated Press',
#        'publicationDate': {'confident': 'no', 'date': '20170126T032100'},
#        'text': 'Asked to comment on a draft executive order that President Donald Trump is expected to sign this week, Russian President Vladimir Putin\'s spokesman, Dmitry Peskov, underlined the importance to "thoroughly calculate all possible consequences" of the measure. He noted Thursday that "it\'s important not to exacerbate the situation with refugees." ...',
#        'title': 'Kremlin: US plan for safe zones in Syria needs to be careful | SunHerald',
#        'url': 'http://www.sunherald.com/news/nation-world/article128840429.html'}}},
#     'timestamp': 1485423320},
#    {'id': 'MjY0MjMxNjU3OXwxNDg1NDIzMzA4',
#     'source': {'enriched': {'url': {'author': '',
#        'publicationDate': {'confident': 'no', 'date': '20170126T112700'},
#        'text': 'US President Donald Trump is planning substantial cuts in US funding for UN agencies whose policy or activity differs from his\xa0administration\'s policy, including US agencies that support Palestinians, "The New York Times" reported yesterday. According to the newspaper, the new administration is already drafting\xa0two executive orders preparing the ground for a "drastic" reduction in US involvement in the activity of international agencies. ...',
#        'title': 'Trump to cut support for Palestinian-funding UN agencies - Globes English',
#        'url': 'http://www.globes.co.il/en/article-trump-to-cut-support-for-palestinian-funding-un-agencies-1001173838'}}},
#     'timestamp': 1485423308},
#    {'id': 'MjYzMDUwMDY5MnwxNDg1NDIzMjc0',
#     'source': {'enriched': {'url': {'author': 'Julie Beck',
#        'publicationDate': {'confident': 'no', 'date': '20170125T000000'},
#        'text': 'If someone’s about to go into a cold swimming pool, they’ll probably use one of two tactics. They might dip a toe in, wade in to the ankles, and slowly, slowly inch their body into the water until they’re completely submerged. ...',
#        'title': 'Does Corruption Happen Slowly, or All At Once?',
#        'url': 'https://www.theatlantic.com/science/archive/2017/01/cannonball-into-corruption/514433/'}}},
#     'timestamp': 1485423274},
#    {'id': 'MjYyOTcwNDU0OXwxNDg1NDIzMjUx',
#     'source': {'enriched': {'url': {'author': 'Gary Naylor',
#        'publicationDate': {'confident': 'no', 'date': '20170126T000000'},
#        'text': 'It seems required in 2017 to reference either Donald Trump or La La Land - so... Dirty Great Love Story has absolutely nothing in common with the President of the United States. There is some escape. ...',
#        'title': 'BWW Review: DIRTY GREAT LOVE STORY, Arts Theatre',
#        'url': 'http://www.broadwayworld.com/westend/article/BWW-Review-DIRTY-GREAT-LOVE-STORY-Arts-Theatre-20170126'}}},
#     'timestamp': 1485423251},
#    {'id': 'MjY0MTc3NDM5OXwxNDg1NDIzMjUx',
#     'source': {'enriched': {'url': {'author': 'TradeTheNews.com Staff',
#        'publicationDate': {'confident': 'no', 'date': '20460801T000000'},
#        'text': "- German Jan IFO Survey missed expectations as Business Climate retreats from 3-year highs (109.8 v 111.3e)\nAsia:\n- Australia Q4 CPI Q/Q: 0.5% v 0.7%e; Y/Y: 1.5% v 1.6%e; surprisingly subdued, rekindles rate cut hopes\n- Japan Dec Trade Balance beats expectations (¥641B v ¥281Be) as exports rose for 1st time in 15 months; Overall Trade Balance registers its 1st surplus in six years\n- PBOC should create interest rate corridor to stabilize short-term interest rates and market expectations\nEurope: \n- ECB's Lautenschlaeger (Germany) was optimistic that ECB could soon turn to question of QE exit strategy and stressed it needed to prepare to act when time comes\nAmericas:\n- President Trump to sign an executive order on Wednesday to allocate federal funds for construction of a wall on Mexican border\n- US Senate Democratic Leader Schumer: President Trump should label China an currency manipulator\n Energy: \n- (US) Weekly API Oil Inventories: Crude: +2.9M v -5.0M prior\n- (CH) Swiss Dec UBS Consumption Indicator: 1.50 v 1.45 prior\n- (FR) France Jan Business Confidence (miss): 104 v 105e; Manufacturing Confidence: 106 v 106e, Production Outlook Indicator: 8 v 6e, Own-Company Production Outlook: 11 v 8e\n- (FR) France Jan Business Survey Overall Demand: 11 v 3 prior\n- (DE) Germany Jan IFO Business Climate (miss): 109.8 v 111.3e; Current Assessment: 116.9 v 117.0e, Expectations Survey: 103.2 v 105.8e\n- (PL) Poland Dec Unemployment Rate: 8.3% v 8.3%e\n **Fixed Income Issuance: \n- (IN) India sold INR100B vs. INR100B indicated in 3-month and 6-month Bills (INR60B and INR40B respectively)\n- (EU) ECB allotted $270M in 7-day USD Liquidity Tender at 1.15% vs. $265M prior\n- (SE) Sweden sold SEK3.0B vs. ...",
#        'title': 'German IFO survey moves off 3 year highs',
#        'url': 'https://www.fxstreet.com/analysis/german-ifo-survey-moves-off-3-year-highs-201701251051'}}},
#     'timestamp': 1485423251},
#    {'id': 'MjY0MTMxNTYzN3wxNDg1NDIzMTg3',
#     'source': {'enriched': {'url': {'author': '',
#        'publicationDate': {'confident': 'no', 'date': '20160930T000000'},
#        'text': '               FILE - In this Sept. 30, 2016 file photo, a Filipino trader stands in front of an electronic board showing major Asian markets during afternoon trading at the Philippine Stock Exchange in the financial district of Makati, south of Manila, Philippines. Officials report the Philippine economy expanded at a 6.6 percent annual rate in October-December, the slowest pace of expansion for the year, though full-year annual growth clocked in at a relatively brisk 6.8 percent. ...',
#        'title': 'Philippines GDP grows 6.6 pct in Oct-Dec, 6.8 pct for year',
#        'url': 'https://apnews.com/e8220417c3f049738ecaf5e4128b3459'}}},
#     'timestamp': 1485423187},
#    {'id': 'MjYyOTA0ODMwMXwxNDg1NDIzMTUz',
#     'source': {'enriched': {'url': {'author': 'JULIE PACE AP White House Correspondent',
#        'publicationDate': {'confident': 'no', 'date': '20170126T040700'},
#        'text': 'President Donald Trump\'s wide-ranging executive actions tightening border security— and the prospect of additional measures restricting refugee flows — mark a sharp shift away from Washington\'s elusive efforts to forge comprehensive immigration legislation. "We do not need new laws," Trump said Wednesday during remarks at the Department of Homeland Security. ...',
#        'title': "Trump's immigration actions mark sharp shift in US policy | Centre Daily Times",
#        'url': 'http://www.centredaily.com/news/nation-world/article128840364.html'}}},
#     'timestamp': 1485423153},
#    {'id': 'MjYyOTQ4NjMyOXwxNDg1NDIzMTQz',
#     'source': {'enriched': {'url': {'author': 'NANCY BENAC Associated Press',
#        'publicationDate': {'confident': 'no', 'date': '20170126T035600'},
#        'text': 'Immigration to the United States has come in swells and dips over the past two-plus centuries, driven by shifts in U.S. policy, the mood in the country and world events. Labor shortages, racial tension, economic forces, religious prejudice and national security concerns all fit into the picture. ...',
#        'title': 'Doing the wave: A primer on immigration in America | Centre Daily Times',
#        'url': 'http://www.centredaily.com/news/nation-world/article128840349.html'}}},
#     'timestamp': 1485423143},
#    {'id': 'MjYyOTUwODUzNHwxNDg1NDIzMTIz',
#     'source': {'enriched': {'url': {'author': 'Dhruba Raj Adhikari print',
#        'publicationDate': {'confident': 'no', 'date': '20170126T000000'},
#        'text': ' Donald J. Trump has been sworn in as the 45th president of the US. The relationship between two world-powers-- the US and China is already at a crossroads with his rise in US politics. The Chinese leadership is anxious while Russia’s strongman Vladimir Putin seems to be jubilant. ...',
#        'title': 'Welcome to the Trumped World (Dis)Order!',
#        'url': 'http://setopati.net/blog/20014/Welcome-to-the-Trumped-World-(Dis)Order!/'}}},
#     'timestamp': 1485423123}],
#   'next': '',
#   'status': 'OK'},
#  'status': 'OK',
#  'totalTransactions': '98',
#  'usage': 'By accessing AlchemyAPI or using information generated by AlchemyAPI, you are agreeing to be bound by the AlchemyAPI Terms of Use: http://www.alchemyapi.com/company/terms.html'}
