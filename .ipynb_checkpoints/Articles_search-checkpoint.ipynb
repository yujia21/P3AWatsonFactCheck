# %%
# !jupyter nbconvert --to script Articles_search.ipynb

from watson_developer_cloud import AlchemyDataNewsV1
import json
# Out:
# [NbConvertApp] Converting notebook Articles_search.ipynb to script
# [NbConvertApp] Writing 2107 bytes to Articles_search.py

# %%
from API_Key import *
from Keyword_input import extract_keywords
alchemy_data_news = AlchemyDataNewsV1(api_key = api_key_chosen)

# %%
def search_from_keywords(keywords):
    
    # keywords is a list of lists : 
    # [relations, negations, dates]
    # relations is a list [(list subjects, list of objects, relation)]. 
    # List of subjects can be ['president','Trump'] or just ['member']
    # negations and dates can be empty. Else : date = [(datetime, original text)]
    
    interesting_keywords = []
    for intermediate_list in list(keywords['subjects'].values()):
        interesting_keywords += intermediate_list
    
    for word in keywords['objects']:
        if word not in interesting_keywords:
            interesting_keywords.append(word)
    
    tts='A['
    for keyword in interesting_keywords:
        tts += keyword+'^'
    tts = tts[:-1]+']'

    results = alchemy_data_news.get_news_documents(
                                                   start='now-1d',
                                                   end='now',
                                                   return_fields=['enriched.url.title',
                                                                  'enriched.url.url',
                                                                  'enriched.url.text',
                                                                  'enriched.url.author',
                                                                  'enriched.url.publicationDate'],
                                                   query_fields={'q.enriched.url.text': tts})
    
    #print(json.dumps(results, indent=2))
    
    text_list = [doc['source']['enriched']['url']['text'] for doc in results['result']['docs']]
    
    keywords_list = [extract_keywords(text) for text in text_list]
    
    return keywords_list

# %%
def search_from_keywords_wiki(keywords):
    import wikipedia
    
    interesting_keywords = []
    
    #Keys of keywords :
    #subjects['Person']
    #subjects['Country']
    #subjects['Organization']
    #subjects['Unsorted Subjects']
    #relations
    #objects
    
    person_pages = []
    for person in keywords['subjects']['Person']:
        temp_person = wikipedia.page(person)
        person_pages.append(temp_person)
        
        # object
        for object_search in keywords['objects'].values():
            # if object in page
            if object_search in temp_person.contents :
                # return sentence with object and subject
                keywords_list.append('sentence with object and subject')
    
    return keywords_list

# %%
'''
# Comment if using from Interface, decomment to test.
k = {'subjects': {'Person': ['Trump'], 'Unsorted Subjects': []}, 'objects': ['president']}

search_from_keywords(k)
'''
# Out:
# This fact is about:
# Unsorted Subjects :
# ['said', 'said']
# Person :
# ['President Donald Trump']
# Organization :
# ['Department of Homeland Security.']
#
# The relations and verbs involved are:
# ['worksAs', 'agentOf', 'timeOf']
#
# The objects of these relations are:
# ['executive', 'said', 'said']
#
#
# ## Negations ##
# There is a negation : ['not']
#
#
# This fact is about:
# Unsorted Subjects :
# ['Mexico', 'negotiations', 'US', 'administration', 'election campaign', 'vowed', 'vowed', 'Mexican']
# Country :
# ['Mexico', 'US']
# Person :
# ['Donald Trump']
#
# The relations and verbs involved are:
# ['worksAs', 'locatedAt', 'timeOf', 'managerOf', 'managerOf', 'agentOf', 'agentOf', 'partOf', 'employedBy']
#
# The objects of these relations are:
# ['President', 'Mexico', 'negotiations', 'US', 'administration', 'election campaign', 'vowed', 'vowed', 'Mexican']
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['call', 'White House', 'meeting', 'say', 'call', 'world', 'meeting', 'meeting', 'inauguration', 'inauguration', 'inauguration', 'meeting']
# Country :
# ['Britain', 'US', 'UK']
# Person :
# ['Donald Trump', 'Theresa']
#
# The relations and verbs involved are:
# ['worksAs', 'worksAs', 'agentOf', 'locatedAt', 'participantIn', 'agentOf', 'timeOf', 'partOfMany', 'participantIn', 'timeOf', 'agentOf', 'participantIn', 'timeOf', 'timeOf']
#
# The objects of these relations are:
# ['Prime Minister', 'president', 'call', 'White House', 'meeting', 'say', 'call', 'world', 'meeting', 'meeting', 'inauguration', 'inauguration', 'inauguration', 'meeting']
#
#
#
# This fact is about:
# Country :
# ['United States']
#
# The relations and verbs involved are:
# []
#
# The objects of these relations are:
# []
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['discussions', 'Malaysia', 'writes', 'US', 'honored', 'Trans-Pacific Partnership', 'indicated']
# Country :
# ['CANADA', 'Vietnam', 'Japan', 'Malaysia']
# Person :
# ['Donald Trump', 'Bruce Cochrane']
# Organization :
# ['Canadian Meat Council']
#
# The relations and verbs involved are:
# ['worksAs', 'worksAs', 'participantIn', 'locatedAt', 'agentOf', 'managerOf', 'affectedBy', 'educatedAt', 'agentOf']
#
# The objects of these relations are:
# ['President', 'executive', 'discussions', 'Malaysia', 'writes', 'US', 'honored', 'Trans-Pacific Partnership', 'indicated']
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['urged', 'United States', 'urged', 'America']
# Country :
# ['US', 'Mexico']
# Organization :
# ['US Dairy Export Council', 'National Milk Producers Federation', 'Trump Administration', 'USDEC', 'NMPF']
#
# The relations and verbs involved are:
# ['agentOf', 'partOf', 'affectedBy', 'residesIn']
#
# The objects of these relations are:
# ['urged', 'United States', 'urged', 'America']
#
#
# ## Negations ##
# There is a negation : ['not']
#
#
# This fact is about:
# Person :
# ['Donald Trump', 'Albert R. Hunt']
#
# The relations and verbs involved are:
# []
#
# The objects of these relations are:
# []
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['Alabama', 'Women', 'Washington', 'D.C.', 'D.C.', 'Alabama']
#
# The relations and verbs involved are:
# ['residesIn', 'partOfMany', 'residesIn', 'residesIn', 'locatedAt', 'residesIn']
#
# The objects of these relations are:
# ['Alabama', 'Women', 'Washington', 'D.C.', 'D.C.', 'Alabama']
#
#
# ## Negations ##
# There is a negation : ['not']
#
#
# This fact is about:
# Unsorted Subjects :
# ['declared', 'administration']
# Country :
# ['United States.']
# Person :
# ['President Donald Trump']
#
# The relations and verbs involved are:
# ['agentOf', 'managerOf']
#
# The objects of these relations are:
# ['declared', 'administration']
#
#
#
# This fact is about:
# Unsorted Subjects :
# ['Berlin']
# Country :
# ['Germany']
# Organization :
# ['German government']
#
# The relations and verbs involved are:
# ['basedIn']
#
# The objects of these relations are:
# ['Berlin']
# [{'negations': ['not'],
#   'objects': ['executive', 'said', 'said'],
#   'relations': ['worksAs', 'agentOf', 'timeOf'],
#   'subjects': {'Country': [],
#    'Organization': ['Department of Homeland Security.'],
#    'Person': ['President Donald Trump'],
#    'Unsorted Subjects': ['said', 'said']}},
#  {'negations': [],
#   'objects': ['President',
#    'Mexico',
#    'negotiations',
#    'US',
#    'administration',
#    'election campaign',
#    'vowed',
#    'vowed',
#    'Mexican'],
#   'relations': ['worksAs',
#    'locatedAt',
#    'timeOf',
#    'managerOf',
#    'managerOf',
#    'agentOf',
#    'agentOf',
#    'partOf',
#    'employedBy'],
#   'subjects': {'Country': ['Mexico', 'US'],
#    'Organization': [],
#    'Person': ['Donald Trump'],
#    'Unsorted Subjects': ['Mexico',
#     'negotiations',
#     'US',
#     'administration',
#     'election campaign',
#     'vowed',
#     'vowed',
#     'Mexican']}},
#  {'negations': [],
#   'objects': ['Prime Minister',
#    'president',
#    'call',
#    'White House',
#    'meeting',
#    'say',
#    'call',
#    'world',
#    'meeting',
#    'meeting',
#    'inauguration',
#    'inauguration',
#    'inauguration',
#    'meeting'],
#   'relations': ['worksAs',
#    'worksAs',
#    'agentOf',
#    'locatedAt',
#    'participantIn',
#    'agentOf',
#    'timeOf',
#    'partOfMany',
#    'participantIn',
#    'timeOf',
#    'agentOf',
#    'participantIn',
#    'timeOf',
#    'timeOf'],
#   'subjects': {'Country': ['Britain', 'US', 'UK'],
#    'Organization': [],
#    'Person': ['Donald Trump', 'Theresa'],
#    'Unsorted Subjects': ['call',
#     'White House',
#     'meeting',
#     'say',
#     'call',
#     'world',
#     'meeting',
#     'meeting',
#     'inauguration',
#     'inauguration',
#     'inauguration',
#     'meeting']}},
#  {'negations': [],
#   'objects': [],
#   'relations': [],
#   'subjects': {'Country': ['United States'],
#    'Organization': [],
#    'Person': [],
#    'Unsorted Subjects': []}},
#  {'negations': [],
#   'objects': ['President',
#    'executive',
#    'discussions',
#    'Malaysia',
#    'writes',
#    'US',
#    'honored',
#    'Trans-Pacific Partnership',
#    'indicated'],
#   'relations': ['worksAs',
#    'worksAs',
#    'participantIn',
#    'locatedAt',
#    'agentOf',
#    'managerOf',
#    'affectedBy',
#    'educatedAt',
#    'agentOf'],
#   'subjects': {'Country': ['CANADA', 'Vietnam', 'Japan', 'Malaysia'],
#    'Organization': ['Canadian Meat Council'],
#    'Person': ['Donald Trump', 'Bruce Cochrane'],
#    'Unsorted Subjects': ['discussions',
#     'Malaysia',
#     'writes',
#     'US',
#     'honored',
#     'Trans-Pacific Partnership',
#     'indicated']}},
#  {'negations': ['not'],
#   'objects': ['urged', 'United States', 'urged', 'America'],
#   'relations': ['agentOf', 'partOf', 'affectedBy', 'residesIn'],
#   'subjects': {'Country': ['US', 'Mexico'],
#    'Organization': ['US Dairy Export Council',
#     'National Milk Producers Federation',
#     'Trump Administration',
#     'USDEC',
#     'NMPF'],
#    'Person': [],
#    'Unsorted Subjects': ['urged', 'United States', 'urged', 'America']}},
#  {'negations': [],
#   'objects': [],
#   'relations': [],
#   'subjects': {'Country': [],
#    'Organization': [],
#    'Person': ['Donald Trump', 'Albert R. Hunt'],
#    'Unsorted Subjects': []}},
#  {'negations': ['not'],
#   'objects': ['Alabama', 'Women', 'Washington', 'D.C.', 'D.C.', 'Alabama'],
#   'relations': ['residesIn',
#    'partOfMany',
#    'residesIn',
#    'residesIn',
#    'locatedAt',
#    'residesIn'],
#   'subjects': {'Country': [],
#    'Organization': [],
#    'Person': [],
#    'Unsorted Subjects': ['Alabama',
#     'Women',
#     'Washington',
#     'D.C.',
#     'D.C.',
#     'Alabama']}},
#  {'negations': [],
#   'objects': ['declared', 'administration'],
#   'relations': ['agentOf', 'managerOf'],
#   'subjects': {'Country': ['United States.'],
#    'Organization': [],
#    'Person': ['President Donald Trump'],
#    'Unsorted Subjects': ['declared', 'administration']}},
#  {'negations': [],
#   'objects': ['Berlin'],
#   'relations': ['basedIn'],
#   'subjects': {'Country': ['Germany'],
#    'Organization': ['German government'],
#    'Person': [],
#    'Unsorted Subjects': ['Berlin']}}]
