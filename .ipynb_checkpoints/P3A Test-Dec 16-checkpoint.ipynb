# %%
from alchemyapi import AlchemyAPI
import json
alchemyapi = AlchemyAPI()

from ipywidgets import widgets, interact
from IPython.display import display

# %%
def extract_keywords(inputfact):
    print("Your text is : "+inputfact)
    
    import re
    n_list=[]
    #negation
    negation=False
    for n in ["no", "not", "never", "none", "noone"] : 
        if n in re.compile('\w+').findall(inputfact):
            negation=True
            n_list.append(n)

    
    #keywords
    response = alchemyapi.combined("text", inputfact)
    if response['status'] == 'OK' : 
        print('## Keywords ##')
        for keyword in response['keywords']:
            print('text: ', keyword['text'].encode('utf-8'))
            print('relevance: ', keyword['relevance'])
        print('')
        
        print('## Entities ##')
        for entity in response['entities']:
            print('text: ', entity['text'].encode('utf-8'))
            print('type: ', entity['type'])
            print('relevance: ', entity['relevance'])
        print('')
        
        print('## Relations ##')
        response_relations = alchemyapi.relations("text", inputfact)
        for relation in response_relations['relations']:
            print('subject: ', relation['subject']['text'].encode('utf-8'))
            print('action: ', relation['action']['text'].encode('utf-8'))
            print('object: ', relation['subject']['text'].encode('utf-8'))
        
        if (negation) : 
            print('')
            print('## Negations ##')
            if (len(n_list)==1) : 
                print("There is a negation : ", end='')
                print(n_list)
            else : 
                print("There are negations : ", end='')
                print(n_list)
                
        # extract and return keywords, entities, relations and negation -> feed to webpage search
        # Prepositions ? 
        # Concepts ? 
        # Semantic query expansion
        # dbpedia : Quepy
        # Scoping problem - classifier (~Jeopardy). Sample queries
        
    else:
        print('Error in keyword extaction call: ', response['statusInfo'])
    print('')
    print('')

# %%
while (True) : 
    print ("Enter a fact:")
    inputfact = input()
    extract_keywords(inputfact)
# Out:
# Enter a fact:
# Singapore is in China
# Your text is : Singapore is in China
# HTTPConnectionPool(host='access.alchemyapi.com', port=80): Max retries exceeded with url: /calls/text/TextGetCombinedData?outputMode=json&apikey=6b686d275c4cce6fe46efcbffd38a73f526c921c (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fbfff3c29e8>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# Error in keyword extaction call:  network-error
#
#
# Enter a fact:
# Singapore is in China
# Your text is : Singapore is in China
# ## Keywords ##
# text:  b'Singapore'
# relevance:  0.919195
# text:  b'China'
# relevance:  0.910255
#
# ## Entities ##
# text:  b'Singapore'
# type:  Country
# relevance:  0.33
# text:  b'China'
# type:  Country
# relevance:  0.33
#
# ## Relations ##
# subject:  b'Singapore'
# action:  b'is'
# object:  b'Singapore'
#
#
# Enter a fact:
# Sarkozy is not in the French presidentials
# Your text is : Sarkozy is not in the French presidentials
# ## Keywords ##
# text:  b'French presidentials'
# relevance:  0.945652
# text:  b'Sarkozy'
# relevance:  0.503795
#
# ## Entities ##
# text:  b'Sarkozy'
# type:  Person
# relevance:  0.33
#
# ## Relations ##
# subject:  b'Sarkozy'
# action:  b'is'
# object:  b'Sarkozy'
#
# ## Negations ##
# There is a negation : ['not']
#
#
# Enter a fact:
# Boeing is building a brand new 747 Air Force One for future presidents, but costs are out of control, more than $4 billion. Cancel order!
# Your text is : Boeing is building a brand new 747 Air Force One for future presidents, but costs are out of control, more than $4 billion. Cancel order!
# HTTPConnectionPool(host='access.alchemyapi.com', port=80): Max retries exceeded with url: /calls/text/TextGetCombinedData?outputMode=json&apikey=6b686d275c4cce6fe46efcbffd38a73f526c921c (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fbfff3c75f8>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# Error in keyword extaction call:  network-error
#
#
# Enter a fact:
# Boeing is building a brand new 747 Air Force One for future presidents, but costs are out of control, more than $4 billion. Cancel order!
# Your text is : Boeing is building a brand new 747 Air Force One for future presidents, but costs are out of control, more than $4 billion. Cancel order!
# ## Keywords ##
# text:  b'Cancel order'
# relevance:  0.945444
# text:  b'future presidents'
# relevance:  0.924851
# text:  b'Air Force'
# relevance:  0.763376
# text:  b'Boeing'
# relevance:  0.589874
# text:  b'costs'
# relevance:  0.512765
# text:  b'brand'
# relevance:  0.395174
# text:  b'control'
# relevance:  0.389807
#
# ## Entities ##
# text:  b'Boeing'
# type:  Company
# relevance:  0.914213
# text:  b'$4 billion'
# type:  Quantity
# relevance:  0.914213
#
# ## Relations ##
# subject:  b'Boeing'
# action:  b'is'
# object:  b'Boeing'
# subject:  b'Boeing'
# action:  b'is building'
# object:  b'Boeing'
# subject:  b'costs'
# action:  b'are'
# object:  b'costs'
#
#
# Enter a fact:
# Sarkozy is not in the French Presidentials
# Your text is : Sarkozy is not in the French Presidentials
# HTTPConnectionPool(host='access.alchemyapi.com', port=80): Max retries exceeded with url: /calls/text/TextGetCombinedData?outputMode=json&apikey=6b686d275c4cce6fe46efcbffd38a73f526c921c (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fbfff3c7780>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# Error in keyword extaction call:  network-error
#
#
# Enter a fact:
# Sarkozy is not in the French Presidentials
# Your text is : Sarkozy is not in the French Presidentials
# ## Keywords ##
# text:  b'French Presidentials'
# relevance:  0.945652
# text:  b'Sarkozy'
# relevance:  0.503795
#
# ## Entities ##
# text:  b'Sarkozy'
# type:  Person
# relevance:  0.33
# text:  b'French Presidentials'
# type:  GeographicFeature
# relevance:  0.33
#
# ## Relations ##
# subject:  b'Sarkozy'
# action:  b'is'
# object:  b'Sarkozy'
#
# ## Negations ##
# There is a negation : ['not']
#
#
# Enter a fact:
# Obama is dead
# Your text is : Obama is dead
# ## Keywords ##
# text:  b'Obama'
# relevance:  0.986345
#
# ## Entities ##
# text:  b'Obama'
# type:  Person
# relevance:  0.33
#
# ## Relations ##
#
#
# Enter a fact:
# New York is in France
# Your text is : New York is in France
# ## Keywords ##
# text:  b'New York'
# relevance:  0.984403
# text:  b'France'
# relevance:  0.669109
#
# ## Entities ##
# text:  b'New York'
# type:  City
# relevance:  0.33
# text:  b'France'
# type:  Country
# relevance:  0.33
#
# ## Relations ##
# subject:  b'New York'
# action:  b'is'
# object:  b'New York'
#
#
# Enter a fact:
