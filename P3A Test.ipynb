# %%
from alchemyapi import AlchemyAPI
import json
alchemyapi = AlchemyAPI()

from ipywidgets import widgets, interact
from IPython.display import display

# %%
def extract_keywords(inputfact):
    print("Your text is : "+inputfact)
    
    import re
    n_list=[]
    #negation
    negation=False
    for n in ["no", "not", "never", "none", "noone"] : 
        if n in re.compile('\w+').findall(inputfact):
            negation=True
            n_list.append(n)

    
    #keywords
    response = alchemyapi.combined("text", inputfact)
    if response['status'] == 'OK' : 
        print('## Keywords ##')
        for keyword in response['keywords']:
            print('text: ', keyword['text'].encode('utf-8'))
            print('relevance: ', keyword['relevance'])
        print('')
        
        print('## Entities ##')
        for entity in response['entities']:
            print('text: ', entity['text'].encode('utf-8'))
            print('type: ', entity['type'])
            print('relevance: ', entity['relevance'])
        print('')
        
        print('## Relations ##')
        response_relations = alchemyapi.relations("text", inputfact)
        for relation in response_relations['relations']:
            print('subject: ', relation['subject']['text'].encode('utf-8'))
            print('action: ', relation['action']['text'].encode('utf-8'))
            print('object: ', relation['subject']['text'].encode('utf-8'))
        
        if (negation) : 
            print('')
            print('## Negations ##')
            if (len(n_list)==1) : 
                print("There is a negation : ", end='')
                print(n_list)
            else : 
                print("There are negations : ", end='')
                print(n_list)
                
        # extract and return keywords, entities, relations and negation -> feed to webpage search
        
    else:
        print('Error in keyword extaction call: ', response['statusInfo'])
    print('')
    print('')

# %%
while (True) : 
    print ("Enter a fact:")
    inputfact = input()
    extract_keywords(inputfact)
# Out:
# Enter a fact:
# Obama is not dead
# Your text is : Obama is not dead
# ## Keywords ##
# text:  b'Obama'
# relevance:  0.986345
#
# ## Entities ##
# text:  b'Obama'
# type:  Person
# relevance:  0.33
#
# ## Concepts ##
#
# ## Relations ##
#
# ## Negations ##
# There is a negation : ['not']
#
#
# Enter a fact:
# Obama does not live in the white house
# Your text is : Obama does not live in the white house
# HTTPConnectionPool(host='access.alchemyapi.com', port=80): Max retries exceeded with url: /calls/text/TextGetCombinedData?outputMode=json&apikey=6b686d275c4cce6fe46efcbffd38a73f526c921c (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fbfff3bdb00>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# Error in keyword extaction call:  network-error
#
#
# Enter a fact:
# Obama does not live in the white house
# Your text is : Obama does not live in the white house
# ## Keywords ##
# text:  b'white house'
# relevance:  0.974088
# text:  b'Obama'
# relevance:  0.814436
#
# ## Entities ##
# text:  b'Obama'
# type:  Person
# relevance:  0.33
# text:  b'white house'
# type:  Facility
# relevance:  0.33
#
# ## Concepts ##
# text:  b'President of the United States'
# relevance:  0.942802
# text:  b'Bill Clinton'
# relevance:  0.917387
# text:  b'White House'
# relevance:  0.90459
# text:  b'Thomas Jefferson'
# relevance:  0.712345
# text:  b'United States Capitol'
# relevance:  0.685164
# text:  b'Washington, D.C.'
# relevance:  0.644722
# text:  b'First Lady of the United States'
# relevance:  0.619753
# text:  b'Andrew Jackson'
# relevance:  0.602661
# text:  b'Camp David'
# relevance:  0.568696
# text:  b'James Madison'
# relevance:  0.561824
# text:  b'Franklin D. Roosevelt'
# relevance:  0.561322
#
# ## Relations ##
# subject:  b'Obama'
# action:  b'does'
# object:  b'Obama'
# subject:  b'Obama'
# action:  b'live'
# object:  b'Obama'
#
# ## Negations ##
# There is a negation : ['not']
#
#
# Enter a fact:
